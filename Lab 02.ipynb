# %%
#Importação das bibliotecas;
import requests, csv
import pandas as pd

#Ingestão dos dados;
url = 'https://olinda.bcb.gov.br/olinda/servico/PTAX/versao/v1/odata/CotacaoDolarPeriodo(dataInicial=@dataInicial,dataFinalCotacao=@dataFinalCotacao)?@dataInicial=%2701-01-2019%27&@dataFinalCotacao=%2712-31-2025%27&$top=9000&$format=text/csv&$select=cotacaoCompra,cotacaoVenda,dataHoraCotacao'
api_dolar = pd.read_csv(url)
print(api_dolar)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">    cotacaoCompra cotacaoVenda          dataHoraCotacao
# 0          3,8589       3,8595  2019-01-02 13:04:46.568
# 1          3,7677       3,7683  2019-01-03 13:04:50.817
# 2          3,7621       3,7627  2019-01-04 13:06:29.332
# 3          3,7056       3,7062  2019-01-07 13:09:39.652
# 4          3,7202       3,7208   2019-01-08 13:09:06.45
# ..            ...          ...                      ...
# 768         5,416       5,4166  2022-01-20 13:04:23.016
# 769        5,4395       5,4401  2022-01-21 13:04:25.546
# 770        5,4904        5,491  2022-01-24 13:07:27.017
# 771        5,4965       5,4971  2022-01-25 13:11:44.196
# ...

# %%
#Declaração dataframe;
df=spark.createDataFrame(api_dolar)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
#Conecção com o SQL Server;
nome_servidor = 'sql-estudo.database.windows.net'
database = "db-estudos"
port_connection = 1433
user = 'admin-azure'
password = 'a&Ehs&HB'
jdbcUrl = "jdbc:sqlserver://{0}:{1};database={2};user={3};password= {4}".format(nome_servidor, port_connection, database, user, password)

df.write.jdbc(jdbcUrl, "dolar2_guilherme_stevanatto.dolar2_stage_guilherme_stevanatto", mode='overwrite')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
